# %% [markdown]
# # Запуск проекта в Google Colab

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content
# !git clone https://github.com/Batyaoftheyear/diffusion-cats-ddpm-ddim.git
# %cd /content/diffusion-cats-ddpm-ddim
# !pip install -r requirements.txt

# %%
# !python train.py --config config.yaml --num_epochs 300 --output_dir /content/drive/MyDrive/diffusion_cats_outputs_300_3

# %%
# !python sample.py --checkpoint /content/drive/MyDrive/diffusion_cats_outputs_300_3/checkpoints/best.pt --method ddpm --steps 1000 --num_images 16 --batch_size 16

# %%
# !python sample.py --checkpoint /content/drive/MyDrive/diffusion_cats_outputs_300_3/checkpoints/best.pt --method ddim --steps 300
