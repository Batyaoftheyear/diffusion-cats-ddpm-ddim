# %% [markdown]
# # Запуск проекта в Google Colab
#
# Ноутбук устанавливает зависимости, при необходимости монтирует Google Drive, запускает обучение и затем отдельно запускает DDPM и DDIM сэмплинг.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content
# !git clone https://github.com/Batyaoftheyear/diffusion-cats-ddpm-ddim.git
# %cd /content/diffusion-cats-ddpm-ddim
# !pip install -r requirements.txt

# %%
# !python train.py --config config.yaml --output_dir /content/drive/MyDrive/diffusion_cats_outputs

# %%
# !python sample.py --checkpoint /content/drive/MyDrive/diffusion_cats_outputs/checkpoints/best.pt --method ddpm --steps 1000

# %%
# !python sample.py --checkpoint /content/drive/MyDrive/diffusion_cats_outputs/checkpoints/best.pt --method ddim --steps 100
